# %%
library(readr)

df_sm <- read_csv("2065 Final Abortion.csv")
df_abort <- read_csv("2065 Final Single Mothers.csv")

head(df_sm)
head(df_abort)
# Out:
# Parsed with column specification:
# cols(
#   .default = col_character(),
#   Bans_Prohibit = col_double(),
#   `_caution_Bans_Prohibit` = col_logical(),
#   Prohibit_Req = col_double(),
#   `_caution_Prohibit_Req` = col_logical(),
#   Reason_Prohibit = col_double(),
#   `_caution_Reason_Prohibit` = col_logical(),
#   `_caution_Reason_What` = col_logical(),
#   Methods_Prohibit = col_double(),
#   `_caution_Methods_Prohibit` = col_logical(),
#   Limited_Law = col_double(),
#   `_caution_Limited_Law` = col_logical(),
#   Limited_Court = col_double(),
#   Limited_AG = col_double()
# )
# See spec(...) for full column specifications.
# Warning message:
# “Missing column names filled in: 'X2' [2], 'X3' [3]”Parsed with column specification:
# cols(
#   `Percentage of single mother households in the U.S. 2018, by state` = col_character(),
#   X2 = col_double(),
#   X3 = col_character()
# )
# Warning message in FUN(X[[i]], ...):
# ...
